# %%
#Importing important library.
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings("ignore")
import time

# %%
#Importing Chrome-webriver
driver=webdriver.Chrome(r'"C:\Users\amits\Desktop\chromedriver_win32\chromedriver.exe"')

# %%
#Maximazing windows
driver.maximize_window()

# %%
#Opening Youtube Website
url='https://www.youtube.com/watch?v=qySOXAJW12g&t=7s'
driver.get(url)

# %% [markdown]
# **Scrapping Comments**

# %%
Comments=[]
comment=driver.find_elements(By.ID,"content-text")
for i in comment[:500]:
    Comments.append(i.text)
    
Comments
# Out:
# ['GOOSEBUMPS! Even the dubbing by RKD is just brilliant always! even the dialogues, the usage of Sanskrit words, their dubbing is just so perfect always!',
#  'Last scene of hanuman ji chanting "RAM".....give me goosebump',
#  'The last scene of Hanumanji chanting RAM inside Shivling is divinity at its peak ',
#  'GOOSEBUMPS  \nThat last chanting of HANUMAN ji Ram Ram ️',
#  'Jai bajrangbali ️️ I get goosebumps while watching ️️',
#  'Last scene actually made me join my hands with my eyes close praying and chanting jai shri ram jai hanuman..',
#  'Love Hindu India from Myanmar. We all worship Hanuman.',
#  'My soul is just vibrate from inside when I listening the chanting of Shri Hanuman "RAM RAM"',
#  'Last scene of HANUMAN JI chanting RAM RAM RAM....  Gives goosebumps ️️',
#  'I swear to god … I literally felt goosebumps and my eyes were full of tears while watching this video… \n\nSpecifically the last 10 seconds ',
# ...

# %%
len(Comments)
# Out:
# 500

# %%
Upvote=[]
vote=driver.find_elements(By.XPATH,"//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for i in vote[0:500]:
    Upvote.append(i.text)
    
Upvote
# Out:
# ['',
#  '1.7K',
#  '',
#  '8.4K',
#  '',
#  '1.2K',
#  '',
#  '92',
#  '',
#  '128',
#  '',
#  '93',
#  '',
#  '1.3K',
#  '',
#  '106',
#  '',
#  '390',
#  '',
#  '19',
#  '',
#  '190',
#  '',
#  '3',
#  '',
#  '8.5K',
#  '',
#  '101',
#  '',
#  '96',
#  '',
#  '6',
#  '',
#  '55',
#  '',
#  '3',
#  '',
#  '2K',
#  '',
#  '185',
#  '',
#  '22',
#  '',
#  '6',
#  '',
#  '73',
#  '',
#  '2',
#  '',
#  '1.7K',
#  '',
#  '80',
#  '',
#  '41',
#  '',
#  '1',
#  '',
#  '60',
#  '',
#  '2',
#  '',
#  '954',
#  '',
#  '108',
#  '',
#  '21',
#  '',
#  '2',
#  '',
#  '21',
#  '',
#  '2',
#  '',
#  '1K',
#  '',
#  '59',
#  '',
#  '23',
#  '',
#  '2',
#  '',
#  '24',
#  '',
#  '1',
#  '',
#  '921',
#  '',
#  '46',
#  '',
#  '20',
#  '',
#  '',
#  '',
#  '10',
#  '',
#  '1',
#  '',
#  '2.9K',
#  '',
#  '8',
#  '',
#  '11',
#  '',
#  '',
#  '',
#  '29',
#  '',
#  '',
#  '',
#  '18',
#  '',
#  '12',
#  '',
#  '1',
#  '',
#  '22',
#  '',
#  '1',
#  '',
#  '12K',
#  '',
#  '6',
#  '',
#  '5',
#  '',
# ...

# %%
len(Upvote)
# Out:
# 500

# %%
Time=[]
time=driver.find_elements(By.XPATH,"//a[@class='yt-simple-endpoint style-scope yt-formatted-string']")
for i in time[19:519]:
    Time.append(i.text)
    
Time
# Out:
# ['1 day ago',
#  '4 days ago (edited)',
#  '2 days ago',
#  '9 hours ago',
#  '1 day ago (edited)',
#  '9 hours ago',
#  '2 days ago',
#  '1 day ago',
#  '1 day ago',
#  '4 hours ago',
#  '1 day ago',
#  '2 hours ago',
#  '4 days ago (edited)',
#  '1 day ago',
#  '23 hours ago',
#  '4 hours ago',
#  '1 day ago',
#  '2 hours ago',
#  '2 days ago',
#  '2 days ago',
#  '21 hours ago',
#  '4 hours ago',
#  '1 day ago',
#  '5 hours ago',
#  '3 days ago',
#  '00:52',
#  '01:05',
#  '2 days ago (edited)',
#  '1:21',
#  '1 day ago',
#  '2 hours ago',
#  '1 day ago',
#  '4 hours ago',
#  '3 days ago',
#  '1 day ago',
#  '1 day ago',
#  '7 hours ago',
#  '1 day ago',
#  '2 hours ago',
#  '4 days ago (edited)',
#  '2 days ago',
#  '1 day ago',
#  '7 hours ago',
#  '1:21',
#  '13 hours ago',
#  '1 hour ago',
#  '2 days ago',
#  '1 day ago',
#  '19 hours ago',
#  '36 minutes ago',
#  '1 day ago',
#  '27 minutes ago',
#  '4 days ago (edited)',
#  '1 day ago',
#  '23 hours ago',
# ...

# %%
len(Time)
# Out:
# 500

# %%
Youtube=pd.DataFrame({"Comments In Hanuman":Comments,"Upvote":Upvote,"Time of Comments":Time})
Youtube.head(10)
# Out:
#                                  Comments In Hanuman Upvote  \
# 0  GOOSEBUMPS! Even the dubbing by RKD is just br...
# 1  Last scene of hanuman ji chanting "RAM".....gi...   1.7K
# 2  The last scene of Hanumanji chanting RAM insid...
# 3  GOOSEBUMPS  \nThat last chanting of HANUMAN ji...   8.4K
# 4  Jai bajrangbali ️️ I get goosebumps while watc...
# 5  Last scene actually made me join my hands with...   1.2K
# 6  Love Hindu India from Myanmar. We all worship ...
# 7  My soul is just vibrate from inside when I lis...     92
# 8  Last scene of HANUMAN JI chanting RAM RAM RAM....
# 9  I swear to god … I literally felt goosebumps a...    128
#
#       Time of Comments
# 0            1 day ago
# 1  4 days ago (edited)
# 2           2 days ago
# 3          9 hours ago
# 4   1 day ago (edited)
# 5          9 hours ago
# 6           2 days ago
# 7            1 day ago
# 8            1 day ago
# 9          4 hours ago
